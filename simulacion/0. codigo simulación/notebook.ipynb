# %%
import subprocess
import sys

def correr_paralelo_consola(seeds, script="run_sim.py"):
    procesos = []
    for seed in seeds:
        print(f"🚀 Ejecutando simulación con seed={seed}")
        p = subprocess.Popen([sys.executable, script, str(seed)])
        procesos.append(p)

    for p in procesos:
        p.wait()
    print("✅ Todas las simulaciones han terminado.")

# %%
seeds = list(range(10, 20))
correr_paralelo_consola(seeds)
# Out:
# 🚀 Ejecutando simulación con seed=10
# 🚀 Ejecutando simulación con seed=11
# 🚀 Ejecutando simulación con seed=12
# 🚀 Ejecutando simulación con seed=13
# 🚀 Ejecutando simulación con seed=14
# 🚀 Ejecutando simulación con seed=15
# 🚀 Ejecutando simulación con seed=16
# 🚀 Ejecutando simulación con seed=17
# 🚀 Ejecutando simulación con seed=18
# 🚀 Ejecutando simulación con seed=19
# Se utiliza archivo existente 13_4208.json de pacientes (0.00 segundos)
# Se utiliza archivo existente 14_4208.json de pacientes (0.00 segundos)
# Se utiliza archivo existente 12_4208.json de pacientes (0.00 segundos)
# Pacientes separados por llegada cargados (4.89 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.07 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (4.96 segundos)
# Clase Simulacion instanciada (0.00 segundos)
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
# Se crea archivo 17_4208.json de pacientes (8.45 segundos)
# Se crea archivo 11_4208.json de pacientes (8.55 segundos)
# Se crea archivo 10_4208.json de pacientes (8.50 segundos)
# Se crea archivo 18_4208.json de pacientes (8.55 segundos)
# Se crea archivo 16_4208.json de pacientes (8.65 segundos)
# Se crea archivo 15_4208.json de pacientes (8.58 segundos)
# Se crea archivo 19_4208.json de pacientes (8.72 segundos)
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
# Simulación finalizada en (9.41 segundos)
# Pacientes separados por llegada cargados (6.17 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Simulación finalizada en (9.79 segundos)
# Simulación finalizada en (10.08 segundos)
# Pacientes separados por llegada cargados (6.53 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (6.78 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (6.80 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (6.65 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (6.87 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (7.70 segundos)
# Clase Simulacion instanciada (0.00 segundos)
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
# Log de pacientes terminado como DataFrame (4.35 segundos)
#
# Simulando ciclo 1000 de 4500
# Log de pacientes terminado como DataFrame (4.73 segundos)
# Log de pacientes terminado como DataFrame (5.01 segundos)
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 4000 de 4500
# ✅ KPIs calculados en 3.00s
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
# Simulación finalizada en (9.96 segundos)
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
# Simulación finalizada en (9.32 segundos)
# Simulación finalizada en (10.02 segundos)
# Simulación finalizada en (9.98 segundos)
# Simulación finalizada en (10.16 segundos)
# Simulación finalizada en (10.20 segundos)
# ✅ KPIs calculados en 3.88s
#
# Simulando ciclo 4000 de 4500
# ✅ KPIs calculados en 4.13s
# Simulación finalizada en (10.54 segundos)
# Log de pacientes terminado como DataFrame (10.68 segundos)
# Log de pacientes terminado como DataFrame (11.42 segundos)
# Log de pacientes terminado como DataFrame (11.95 segundos)
# Log de pacientes terminado como DataFrame (11.98 segundos)
# Log de pacientes terminado como DataFrame (13.36 segundos)
# Log de pacientes terminado como DataFrame (14.04 segundos)
# Log de pacientes terminado como DataFrame (12.65 segundos)
# ✅ KPIs calculados en 2.48s
# ✅ KPIs calculados en 3.92s
# ✅ KPIs calculados en 4.04s
# ✅ KPIs calculados en 4.06s
# ✅ KPIs calculados en 4.36s
# ✅ KPIs calculados en 4.41s
# ✅ KPIs calculados en 4.97s
# ✅ Todas las simulaciones han terminado.
