# %%
import subprocess
import sys
import multiprocessing

def correr_paralelo_consola(seeds, script="run_sim.py"):
    max_procesos = multiprocessing.cpu_count()
    print(f"🧠 Usando hasta {max_procesos} procesos simultáneos.")

    procesos = []

    for seed in seeds:
        print(f"🚀 Ejecutando simulación con seed={seed}")
        p = subprocess.Popen([sys.executable, script, str(seed)])
        procesos.append(p)

        if len(procesos) >= max_procesos:
            for p in procesos:
                p.wait()
            procesos = []

    # Esperar procesos restantes
    for p in procesos:
        p.wait()

    print("✅ Todas las simulaciones han terminado.")

# %%
seeds = list(range(1, 2))
correr_paralelo_consola(seeds)
# Out:
# 🧠 Usando hasta 10 procesos simultáneos.
# 🚀 Ejecutando simulación con seed=1
# Se utiliza archivo existente 1_4208.json de pacientes (0.00 segundos)
# Pacientes separados por llegada cargados (3.63 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Error al sacar paciente 66403 de h:3, u: 4
# Traceback (most recent call last):
#   File "/Users/ffontecilla/Desktop/Capstone Git/simulacion/0. codigo simulación/run_sim.py", line 44, in <module>
#     df = simu.simular()
#   File "/Users/ffontecilla/Desktop/Capstone Git/simulacion/0. codigo simulación/clases.py", line 2315, in simular
#     decisiones = self.modelo.tomar_decisiones(self)
#   File "/Users/ffontecilla/Desktop/Capstone Git/simulacion/0. codigo simulación/clases.py", line 1924, in tomar_decisiones
#     self.atender_wl()
#   File "/Users/ffontecilla/Desktop/Capstone Git/simulacion/0. codigo simulación/clases.py", line 1677, in atender_wl
#     demanda_interna_ciclo, _ = self.demandas_internas_por_ciclo()
#   File "/Users/ffontecilla/Desktop/Capstone Git/simulacion/0. codigo simulación/clases.py", line 1527, in demandas_internas_por_ciclo
#     prob, costos = self.probabilidad_terminar_y_costo_espera(paciente)
#   File "/Users/ffontecilla/Desktop/Capstone Git/simulacion/0. codigo simulación/clases.py", line 1489, in probabilidad_terminar_y_costo_espera
#     pmf_los = self.los[hospital_id][unidad_actual][grd]["final_kde_pmf"]
# KeyError: 0
# ✅ Todas las simulaciones han terminado.
