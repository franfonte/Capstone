# %%
import subprocess
import sys
import multiprocessing

def correr_paralelo_consola(seeds, script="run_sim.py"):
    max_procesos = multiprocessing.cpu_count()
    print(f"🧠 Usando hasta {max_procesos} procesos simultáneos.")

    procesos = []

    for seed in seeds:
        print(f"🚀 Ejecutando simulación con seed={seed}")
        p = subprocess.Popen([sys.executable, script, str(seed)])
        procesos.append(p)

        if len(procesos) >= max_procesos:
            for p in procesos:
                p.wait()
            procesos = []

    # Esperar procesos restantes
    for p in procesos:
        p.wait()

    print("✅ Todas las simulaciones han terminado.")

# %%
seeds = list(range(1, 101))
correr_paralelo_consola(seeds)
# Out:
# 🧠 Usando hasta 10 procesos simultáneos.
# 🚀 Ejecutando simulación con seed=1
# 🚀 Ejecutando simulación con seed=2
# 🚀 Ejecutando simulación con seed=3
# 🚀 Ejecutando simulación con seed=4
# 🚀 Ejecutando simulación con seed=5
# 🚀 Ejecutando simulación con seed=6
# 🚀 Ejecutando simulación con seed=7
# 🚀 Ejecutando simulación con seed=8
# 🚀 Ejecutando simulación con seed=9
# 🚀 Ejecutando simulación con seed=10
# Se crea archivo 7_4208.json de pacientes (7.70 segundos)
# Se crea archivo 3_4208.json de pacientes (7.60 segundos)
# Se crea archivo 8_4208.json de pacientes (7.60 segundos)
# Se crea archivo 1_4208.json de pacientes (7.87 segundos)
# Se crea archivo 2_4208.json de pacientes (7.90 segundos)
# Se crea archivo 6_4208.json de pacientes (7.74 segundos)
# Se crea archivo 4_4208.json de pacientes (7.89 segundos)
# Se crea archivo 10_4208.json de pacientes (7.90 segundos)
# Se crea archivo 9_4208.json de pacientes (8.00 segundos)
# Se crea archivo 5_4208.json de pacientes (8.02 segundos)
# Pacientes separados por llegada cargados (6.53 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (6.71 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (6.73 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (6.72 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (6.94 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (6.86 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (7.05 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (7.23 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (7.45 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (7.70 segundos)
# Clase Simulacion instanciada (0.00 segundos)
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
# Simulación finalizada en (21.45 segundos)
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
# Simulación finalizada en (21.78 segundos)
#
# Simulando ciclo 4000 de 4500
# Simulación finalizada en (22.37 segundos)
# Simulación finalizada en (21.93 segundos)
# Simulación finalizada en (22.25 segundos)
# Simulación finalizada en (21.70 segundos)
# Simulación finalizada en (22.33 segundos)
# Simulación finalizada en (22.41 segundos)
# Simulación finalizada en (21.95 segundos)
# Simulación finalizada en (22.23 segundos)
# Log de pacientes terminado como DataFrame (6.50 segundos)
# Log de pacientes terminado como DataFrame (7.73 segundos)
# Log de pacientes terminado como DataFrame (8.09 segundos)
# Log de pacientes terminado como DataFrame (8.30 segundos)
# Log de pacientes terminado como DataFrame (8.75 segundos)
# Log de pacientes terminado como DataFrame (8.91 segundos)
# Log de pacientes terminado como DataFrame (9.08 segundos)
# Log de pacientes terminado como DataFrame (9.08 segundos)
# Log de pacientes terminado como DataFrame (9.15 segundos)
# Log de pacientes terminado como DataFrame (9.80 segundos)
# ✅ KPIs calculados en 5.42s
# ✅ KPIs calculados en 5.99s
# ✅ KPIs calculados en 5.03s
# ✅ KPIs calculados en 5.66s
# ✅ KPIs calculados en 6.61s
# ✅ KPIs calculados en 5.61s
# ✅ KPIs calculados en 6.74s
# ✅ KPIs calculados en 7.58s
# ✅ KPIs calculados en 7.78s
# ✅ KPIs calculados en 6.77s
# 🚀 Ejecutando simulación con seed=11
# 🚀 Ejecutando simulación con seed=12
# 🚀 Ejecutando simulación con seed=13
# 🚀 Ejecutando simulación con seed=14
# 🚀 Ejecutando simulación con seed=15
# 🚀 Ejecutando simulación con seed=16
# 🚀 Ejecutando simulación con seed=17
# 🚀 Ejecutando simulación con seed=18
# 🚀 Ejecutando simulación con seed=19
# 🚀 Ejecutando simulación con seed=20
# Se crea archivo 19_4208.json de pacientes (7.57 segundos)
# Se crea archivo 15_4208.json de pacientes (7.51 segundos)
# Se crea archivo 18_4208.json de pacientes (7.54 segundos)
# Se crea archivo 20_4208.json de pacientes (7.55 segundos)
# Se crea archivo 12_4208.json de pacientes (7.63 segundos)
# Se crea archivo 16_4208.json de pacientes (7.75 segundos)
# Se crea archivo 14_4208.json de pacientes (7.71 segundos)
# Se crea archivo 13_4208.json de pacientes (7.74 segundos)
# Se crea archivo 17_4208.json de pacientes (7.77 segundos)
# Se crea archivo 11_4208.json de pacientes (7.75 segundos)
# Pacientes separados por llegada cargados (6.09 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (6.51 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (6.46 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (6.54 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (6.55 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (6.56 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (6.84 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (7.11 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (7.28 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (7.20 segundos)
# Clase Simulacion instanciada (0.00 segundos)
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
# Simulación finalizada en (20.63 segundos)
# Simulación finalizada en (20.13 segundos)
# Simulación finalizada en (21.08 segundos)
# Simulación finalizada en (20.71 segundos)
# Simulación finalizada en (20.69 segundos)
# Simulación finalizada en (21.68 segundos)
# Simulación finalizada en (21.20 segundos)
# Simulación finalizada en (20.70 segundos)
# Simulación finalizada en (21.39 segundos)
# Simulación finalizada en (20.82 segundos)
# Log de pacientes terminado como DataFrame (9.09 segundos)
# Log de pacientes terminado como DataFrame (9.16 segundos)
# Log de pacientes terminado como DataFrame (9.19 segundos)
# Log de pacientes terminado como DataFrame (9.49 segundos)
# Log de pacientes terminado como DataFrame (9.08 segundos)
# Log de pacientes terminado como DataFrame (9.41 segundos)
# Log de pacientes terminado como DataFrame (9.56 segundos)
# Log de pacientes terminado como DataFrame (9.37 segundos)
# Log de pacientes terminado como DataFrame (10.42 segundos)
# Log de pacientes terminado como DataFrame (10.44 segundos)
# ✅ KPIs calculados en 4.02s
# ✅ KPIs calculados en 4.16s
# ✅ KPIs calculados en 5.98s
# ✅ KPIs calculados en 6.05s
# ✅ KPIs calculados en 6.27s
# ✅ KPIs calculados en 6.17s
# ✅ KPIs calculados en 5.92s
# ✅ KPIs calculados en 6.32s
# ✅ KPIs calculados en 5.05s
# ✅ KPIs calculados en 5.04s
# 🚀 Ejecutando simulación con seed=21
# 🚀 Ejecutando simulación con seed=22
# 🚀 Ejecutando simulación con seed=23
# 🚀 Ejecutando simulación con seed=24
# 🚀 Ejecutando simulación con seed=25
# 🚀 Ejecutando simulación con seed=26
# 🚀 Ejecutando simulación con seed=27
# 🚀 Ejecutando simulación con seed=28
# 🚀 Ejecutando simulación con seed=29
# 🚀 Ejecutando simulación con seed=30
# Se crea archivo 25_4208.json de pacientes (7.49 segundos)
# Se crea archivo 29_4208.json de pacientes (7.35 segundos)
# Se crea archivo 30_4208.json de pacientes (7.33 segundos)
# Se crea archivo 28_4208.json de pacientes (7.31 segundos)
# Se crea archivo 22_4208.json de pacientes (7.47 segundos)
# Se crea archivo 27_4208.json de pacientes (7.35 segundos)
# Se crea archivo 26_4208.json de pacientes (7.38 segundos)
# Se crea archivo 23_4208.json de pacientes (7.45 segundos)
# Se crea archivo 24_4208.json de pacientes (7.51 segundos)
# Se crea archivo 21_4208.json de pacientes (7.45 segundos)
# Pacientes separados por llegada cargados (5.61 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.88 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.87 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (6.06 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.97 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (6.28 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (6.31 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (6.56 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (6.64 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (6.63 segundos)
# Clase Simulacion instanciada (0.00 segundos)
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
# Simulación finalizada en (21.14 segundos)
# Simulación finalizada en (21.24 segundos)
# Simulación finalizada en (21.82 segundos)
# Simulación finalizada en (20.81 segundos)
# Simulación finalizada en (21.55 segundos)
# Simulación finalizada en (21.49 segundos)
# Simulación finalizada en (21.68 segundos)
# Simulación finalizada en (21.45 segundos)
# Simulación finalizada en (21.92 segundos)
# Simulación finalizada en (21.62 segundos)
# Log de pacientes terminado como DataFrame (7.15 segundos)
# Log de pacientes terminado como DataFrame (8.02 segundos)
# Log de pacientes terminado como DataFrame (8.14 segundos)
# Log de pacientes terminado como DataFrame (8.22 segundos)
# Log de pacientes terminado como DataFrame (8.46 segundos)
# Log de pacientes terminado como DataFrame (8.51 segundos)
# Log de pacientes terminado como DataFrame (8.36 segundos)
# Log de pacientes terminado como DataFrame (8.44 segundos)
# Log de pacientes terminado como DataFrame (8.46 segundos)
# Log de pacientes terminado como DataFrame (8.42 segundos)
# ✅ KPIs calculados en 4.65s
# ✅ KPIs calculados en 3.82s
# ✅ KPIs calculados en 4.01s
# ✅ KPIs calculados en 4.55s
# ✅ KPIs calculados en 4.82s
# ✅ KPIs calculados en 4.97s
# ✅ KPIs calculados en 5.76s
# ✅ KPIs calculados en 6.07s
# ✅ KPIs calculados en 6.46s
# ✅ KPIs calculados en 6.99s
# 🚀 Ejecutando simulación con seed=31
# 🚀 Ejecutando simulación con seed=32
# 🚀 Ejecutando simulación con seed=33
# 🚀 Ejecutando simulación con seed=34
# 🚀 Ejecutando simulación con seed=35
# 🚀 Ejecutando simulación con seed=36
# 🚀 Ejecutando simulación con seed=37
# 🚀 Ejecutando simulación con seed=38
# 🚀 Ejecutando simulación con seed=39
# 🚀 Ejecutando simulación con seed=40
# Se crea archivo 35_4208.json de pacientes (7.44 segundos)
# Se crea archivo 32_4208.json de pacientes (7.53 segundos)
# Se crea archivo 31_4208.json de pacientes (7.65 segundos)
# Se crea archivo 36_4208.json de pacientes (7.62 segundos)
# Se crea archivo 40_4208.json de pacientes (7.70 segundos)
# Se crea archivo 37_4208.json de pacientes (7.66 segundos)
# Se crea archivo 34_4208.json de pacientes (7.76 segundos)
# Se crea archivo 39_4208.json de pacientes (7.77 segundos)
# Se crea archivo 33_4208.json de pacientes (7.76 segundos)
# Se crea archivo 38_4208.json de pacientes (7.77 segundos)
# Pacientes separados por llegada cargados (5.04 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.09 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.46 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.65 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.93 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.84 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.92 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (6.03 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (6.12 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (6.05 segundos)
# Clase Simulacion instanciada (0.00 segundos)
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
# Simulación finalizada en (20.26 segundos)
# Simulación finalizada en (20.26 segundos)
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
# Simulación finalizada en (20.12 segundos)
# Simulación finalizada en (20.01 segundos)
# Simulación finalizada en (20.06 segundos)
# Simulación finalizada en (20.58 segundos)
# Simulación finalizada en (19.93 segundos)
# Simulación finalizada en (20.43 segundos)
# Simulación finalizada en (20.83 segundos)
# Simulación finalizada en (20.84 segundos)
# Log de pacientes terminado como DataFrame (3.14 segundos)
# Log de pacientes terminado como DataFrame (5.47 segundos)
# Log de pacientes terminado como DataFrame (8.29 segundos)
# Log de pacientes terminado como DataFrame (8.43 segundos)
# Log de pacientes terminado como DataFrame (8.84 segundos)
# Log de pacientes terminado como DataFrame (8.77 segundos)
# Log de pacientes terminado como DataFrame (8.94 segundos)
# Log de pacientes terminado como DataFrame (8.99 segundos)
# Log de pacientes terminado como DataFrame (8.63 segundos)
# Log de pacientes terminado como DataFrame (8.67 segundos)
# ✅ KPIs calculados en 5.40s
# ✅ KPIs calculados en 5.67s
# ✅ KPIs calculados en 4.74s
# ✅ KPIs calculados en 5.05s
# ✅ KPIs calculados en 5.27s
# ✅ KPIs calculados en 5.57s
# ✅ KPIs calculados en 5.39s
# ✅ KPIs calculados en 5.40s
# ✅ KPIs calculados en 6.30s
# ✅ KPIs calculados en 6.65s
# 🚀 Ejecutando simulación con seed=41
# 🚀 Ejecutando simulación con seed=42
# 🚀 Ejecutando simulación con seed=43
# 🚀 Ejecutando simulación con seed=44
# 🚀 Ejecutando simulación con seed=45
# 🚀 Ejecutando simulación con seed=46
# 🚀 Ejecutando simulación con seed=47
# 🚀 Ejecutando simulación con seed=48
# 🚀 Ejecutando simulación con seed=49
# 🚀 Ejecutando simulación con seed=50
# Se crea archivo 49_4208.json de pacientes (7.63 segundos)
# Se crea archivo 41_4208.json de pacientes (7.82 segundos)
# Se crea archivo 46_4208.json de pacientes (7.77 segundos)
# Se crea archivo 48_4208.json de pacientes (7.85 segundos)
# Se crea archivo 44_4208.json de pacientes (7.85 segundos)
# Se crea archivo 45_4208.json de pacientes (7.94 segundos)
# Se crea archivo 50_4208.json de pacientes (7.91 segundos)
# Se crea archivo 43_4208.json de pacientes (7.97 segundos)
# Se crea archivo 42_4208.json de pacientes (7.98 segundos)
# Se crea archivo 47_4208.json de pacientes (8.05 segundos)
# Pacientes separados por llegada cargados (6.12 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (6.46 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (6.32 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (6.83 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (6.81 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (6.80 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (6.75 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (6.82 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (6.87 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (6.95 segundos)
# Clase Simulacion instanciada (0.00 segundos)
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
# Simulación finalizada en (21.19 segundos)
#
# Simulando ciclo 4000 de 4500
# Simulación finalizada en (21.20 segundos)
# Simulación finalizada en (21.53 segundos)
# Simulación finalizada en (21.23 segundos)
# Simulación finalizada en (21.29 segundos)
# Simulación finalizada en (21.33 segundos)
# Simulación finalizada en (21.31 segundos)
# Simulación finalizada en (21.61 segundos)
# Simulación finalizada en (21.50 segundos)
# Simulación finalizada en (21.76 segundos)
# Log de pacientes terminado como DataFrame (7.78 segundos)
# Log de pacientes terminado como DataFrame (7.62 segundos)
# Log de pacientes terminado como DataFrame (7.87 segundos)
# Log de pacientes terminado como DataFrame (8.54 segundos)
# Log de pacientes terminado como DataFrame (8.76 segundos)
# Log de pacientes terminado como DataFrame (8.77 segundos)
# Log de pacientes terminado como DataFrame (8.90 segundos)
# Log de pacientes terminado como DataFrame (8.80 segundos)
# Log de pacientes terminado como DataFrame (8.98 segundos)
# Log de pacientes terminado como DataFrame (8.75 segundos)
# ✅ KPIs calculados en 3.53s
# ✅ KPIs calculados en 5.59s
# ✅ KPIs calculados en 4.78s
# ✅ KPIs calculados en 4.63s
# ✅ KPIs calculados en 4.53s
# ✅ KPIs calculados en 4.99s
# ✅ KPIs calculados en 4.80s
# ✅ KPIs calculados en 4.88s
# ✅ KPIs calculados en 4.92s
# ✅ KPIs calculados en 6.01s
# 🚀 Ejecutando simulación con seed=51
# 🚀 Ejecutando simulación con seed=52
# 🚀 Ejecutando simulación con seed=53
# 🚀 Ejecutando simulación con seed=54
# 🚀 Ejecutando simulación con seed=55
# 🚀 Ejecutando simulación con seed=56
# 🚀 Ejecutando simulación con seed=57
# 🚀 Ejecutando simulación con seed=58
# 🚀 Ejecutando simulación con seed=59
# 🚀 Ejecutando simulación con seed=60
# Se crea archivo 60_4208.json de pacientes (7.16 segundos)
# Se crea archivo 51_4208.json de pacientes (7.37 segundos)
# Se crea archivo 59_4208.json de pacientes (7.37 segundos)
# Se crea archivo 54_4208.json de pacientes (7.39 segundos)
# Se crea archivo 56_4208.json de pacientes (7.37 segundos)
# Se crea archivo 52_4208.json de pacientes (7.42 segundos)
# Se crea archivo 58_4208.json de pacientes (7.50 segundos)
# Se crea archivo 55_4208.json de pacientes (7.49 segundos)
# Se crea archivo 57_4208.json de pacientes (7.54 segundos)
# Se crea archivo 53_4208.json de pacientes (7.52 segundos)
# Pacientes separados por llegada cargados (5.08 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.58 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.50 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.85 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.98 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (6.04 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (6.06 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (6.27 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (6.21 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (6.33 segundos)
# Clase Simulacion instanciada (0.00 segundos)
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
# Simulación finalizada en (20.07 segundos)
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
# Simulación finalizada en (20.25 segundos)
# Simulación finalizada en (20.09 segundos)
# Simulación finalizada en (19.76 segundos)
# Simulación finalizada en (19.91 segundos)
# Simulación finalizada en (20.08 segundos)
# Simulación finalizada en (20.80 segundos)
# Simulación finalizada en (19.85 segundos)
# Simulación finalizada en (20.21 segundos)
# Simulación finalizada en (20.17 segundos)
# Log de pacientes terminado como DataFrame (2.56 segundos)
# Log de pacientes terminado como DataFrame (6.63 segundos)
# Log de pacientes terminado como DataFrame (7.18 segundos)
# Log de pacientes terminado como DataFrame (7.28 segundos)
# Log de pacientes terminado como DataFrame (7.23 segundos)
# Log de pacientes terminado como DataFrame (7.61 segundos)
# Log de pacientes terminado como DataFrame (7.45 segundos)
# Log de pacientes terminado como DataFrame (7.54 segundos)
# Log de pacientes terminado como DataFrame (7.51 segundos)
# Log de pacientes terminado como DataFrame (7.50 segundos)
# ✅ KPIs calculados en 5.57s
# ✅ KPIs calculados en 3.53s
# ✅ KPIs calculados en 4.41s
# ✅ KPIs calculados en 4.42s
# ✅ KPIs calculados en 4.55s
# ✅ KPIs calculados en 4.30s
# ✅ KPIs calculados en 4.63s
# ✅ KPIs calculados en 4.55s
# ✅ KPIs calculados en 4.53s
# ✅ KPIs calculados en 5.76s
# 🚀 Ejecutando simulación con seed=61
# 🚀 Ejecutando simulación con seed=62
# 🚀 Ejecutando simulación con seed=63
# 🚀 Ejecutando simulación con seed=64
# 🚀 Ejecutando simulación con seed=65
# 🚀 Ejecutando simulación con seed=66
# 🚀 Ejecutando simulación con seed=67
# 🚀 Ejecutando simulación con seed=68
# 🚀 Ejecutando simulación con seed=69
# 🚀 Ejecutando simulación con seed=70
# Se crea archivo 63_4208.json de pacientes (7.16 segundos)
# Se crea archivo 68_4208.json de pacientes (7.07 segundos)
# Se crea archivo 67_4208.json de pacientes (7.23 segundos)
# Se crea archivo 61_4208.json de pacientes (7.24 segundos)
# Se crea archivo 65_4208.json de pacientes (7.26 segundos)
# Se crea archivo 70_4208.json de pacientes (7.29 segundos)
# Se crea archivo 69_4208.json de pacientes (7.31 segundos)
# Se crea archivo 62_4208.json de pacientes (7.33 segundos)
# Se crea archivo 66_4208.json de pacientes (7.35 segundos)
# Se crea archivo 64_4208.json de pacientes (7.33 segundos)
# Pacientes separados por llegada cargados (5.06 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.14 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.34 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.44 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.48 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.38 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.79 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.86 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.85 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.89 segundos)
# Clase Simulacion instanciada (0.00 segundos)
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
# Simulación finalizada en (20.06 segundos)
# Simulación finalizada en (19.69 segundos)
# Simulación finalizada en (19.69 segundos)
# Simulación finalizada en (19.77 segundos)
# Simulación finalizada en (20.38 segundos)
# Simulación finalizada en (19.94 segundos)
# Simulación finalizada en (19.69 segundos)
# Simulación finalizada en (19.99 segundos)
# Simulación finalizada en (19.98 segundos)
# Simulación finalizada en (20.07 segundos)
# Log de pacientes terminado como DataFrame (6.15 segundos)
# Log de pacientes terminado como DataFrame (7.01 segundos)
# Log de pacientes terminado como DataFrame (7.12 segundos)
# Log de pacientes terminado como DataFrame (7.29 segundos)
# Log de pacientes terminado como DataFrame (7.23 segundos)
# Log de pacientes terminado como DataFrame (7.32 segundos)
# Log de pacientes terminado como DataFrame (7.41 segundos)
# Log de pacientes terminado como DataFrame (7.41 segundos)
# Log de pacientes terminado como DataFrame (7.38 segundos)
# Log de pacientes terminado como DataFrame (7.37 segundos)
# ✅ KPIs calculados en 5.31s
# ✅ KPIs calculados en 4.61s
# ✅ KPIs calculados en 4.38s
# ✅ KPIs calculados en 4.81s
# ✅ KPIs calculados en 4.59s
# ✅ KPIs calculados en 4.40s
# ✅ KPIs calculados en 6.40s
# ✅ KPIs calculados en 6.47s
# ✅ KPIs calculados en 6.53s
# ✅ KPIs calculados en 6.63s
# 🚀 Ejecutando simulación con seed=71
# 🚀 Ejecutando simulación con seed=72
# 🚀 Ejecutando simulación con seed=73
# 🚀 Ejecutando simulación con seed=74
# 🚀 Ejecutando simulación con seed=75
# 🚀 Ejecutando simulación con seed=76
# 🚀 Ejecutando simulación con seed=77
# 🚀 Ejecutando simulación con seed=78
# 🚀 Ejecutando simulación con seed=79
# 🚀 Ejecutando simulación con seed=80
# Se crea archivo 79_4208.json de pacientes (7.79 segundos)
# Se crea archivo 80_4208.json de pacientes (7.64 segundos)
# Se crea archivo 78_4208.json de pacientes (7.72 segundos)
# Se crea archivo 73_4208.json de pacientes (7.65 segundos)
# Se crea archivo 74_4208.json de pacientes (7.74 segundos)
# Se crea archivo 75_4208.json de pacientes (7.79 segundos)
# Se crea archivo 72_4208.json de pacientes (7.81 segundos)
# Se crea archivo 77_4208.json de pacientes (7.80 segundos)
# Se crea archivo 76_4208.json de pacientes (7.79 segundos)
# Se crea archivo 71_4208.json de pacientes (7.79 segundos)
# Pacientes separados por llegada cargados (5.99 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (6.09 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.96 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.91 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (6.27 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (6.45 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (6.56 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (6.55 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (6.55 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (6.65 segundos)
# Clase Simulacion instanciada (0.00 segundos)
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
# Simulación finalizada en (19.51 segundos)
# Simulación finalizada en (19.75 segundos)
# Simulación finalizada en (19.92 segundos)
# Simulación finalizada en (19.65 segundos)
# Simulación finalizada en (19.52 segundos)
# Simulación finalizada en (19.42 segundos)
# Simulación finalizada en (19.55 segundos)
# Simulación finalizada en (20.18 segundos)
# Simulación finalizada en (19.42 segundos)
# Simulación finalizada en (19.79 segundos)
# Log de pacientes terminado como DataFrame (6.58 segundos)
# Log de pacientes terminado como DataFrame (6.58 segundos)
# Log de pacientes terminado como DataFrame (6.87 segundos)
# Log de pacientes terminado como DataFrame (7.08 segundos)
# Log de pacientes terminado como DataFrame (7.26 segundos)
# Log de pacientes terminado como DataFrame (7.36 segundos)
# Log de pacientes terminado como DataFrame (7.29 segundos)
# Log de pacientes terminado como DataFrame (7.42 segundos)
# Log de pacientes terminado como DataFrame (7.36 segundos)
# Log de pacientes terminado como DataFrame (7.23 segundos)
# ✅ KPIs calculados en 4.00s
# ✅ KPIs calculados en 4.35s
# ✅ KPIs calculados en 4.18s
# ✅ KPIs calculados en 4.36s
# ✅ KPIs calculados en 4.36s
# ✅ KPIs calculados en 4.62s
# ✅ KPIs calculados en 4.96s
# ✅ KPIs calculados en 6.11s
# ✅ KPIs calculados en 6.10s
# ✅ KPIs calculados en 6.01s
# 🚀 Ejecutando simulación con seed=81
# 🚀 Ejecutando simulación con seed=82
# 🚀 Ejecutando simulación con seed=83
# 🚀 Ejecutando simulación con seed=84
# 🚀 Ejecutando simulación con seed=85
# 🚀 Ejecutando simulación con seed=86
# 🚀 Ejecutando simulación con seed=87
# 🚀 Ejecutando simulación con seed=88
# 🚀 Ejecutando simulación con seed=89
# 🚀 Ejecutando simulación con seed=90
# Se crea archivo 89_4208.json de pacientes (7.87 segundos)
# Se crea archivo 85_4208.json de pacientes (7.40 segundos)
# Se crea archivo 81_4208.json de pacientes (7.32 segundos)
# Se crea archivo 90_4208.json de pacientes (7.48 segundos)
# Se crea archivo 82_4208.json de pacientes (7.47 segundos)
# Se crea archivo 88_4208.json de pacientes (7.56 segundos)
# Se crea archivo 84_4208.json de pacientes (7.50 segundos)
# Se crea archivo 83_4208.json de pacientes (7.51 segundos)
# Se crea archivo 87_4208.json de pacientes (7.52 segundos)
# Se crea archivo 86_4208.json de pacientes (7.57 segundos)
# Pacientes separados por llegada cargados (5.73 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.81 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.97 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.96 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (6.07 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (6.08 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (6.00 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (6.02 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (6.14 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (6.05 segundos)
# Clase Simulacion instanciada (0.00 segundos)
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
# Simulación finalizada en (20.76 segundos)
# Simulación finalizada en (20.26 segundos)
# Simulación finalizada en (20.31 segundos)
# Simulación finalizada en (20.57 segundos)
# Simulación finalizada en (20.82 segundos)
# Simulación finalizada en (20.36 segundos)
# Simulación finalizada en (20.53 segundos)
# Simulación finalizada en (20.56 segundos)
# Simulación finalizada en (20.64 segundos)
# Simulación finalizada en (20.89 segundos)
# Log de pacientes terminado como DataFrame (5.72 segundos)
# Log de pacientes terminado como DataFrame (7.12 segundos)
# Log de pacientes terminado como DataFrame (7.20 segundos)
# Log de pacientes terminado como DataFrame (7.48 segundos)
# Log de pacientes terminado como DataFrame (7.49 segundos)
# Log de pacientes terminado como DataFrame (7.50 segundos)
# Log de pacientes terminado como DataFrame (7.63 segundos)
# Log de pacientes terminado como DataFrame (7.62 segundos)
# Log de pacientes terminado como DataFrame (7.69 segundos)
# Log de pacientes terminado como DataFrame (7.57 segundos)
# ✅ KPIs calculados en 3.70s
# ✅ KPIs calculados en 4.85s
# ✅ KPIs calculados en 5.43s
# ✅ KPIs calculados en 5.47s
# ✅ KPIs calculados en 5.47s
# ✅ KPIs calculados en 5.63s
# ✅ KPIs calculados en 5.47s
# ✅ KPIs calculados en 5.62s
# ✅ KPIs calculados en 5.50s
# ✅ KPIs calculados en 5.69s
# 🚀 Ejecutando simulación con seed=91
# 🚀 Ejecutando simulación con seed=92
# 🚀 Ejecutando simulación con seed=93
# 🚀 Ejecutando simulación con seed=94
# 🚀 Ejecutando simulación con seed=95
# 🚀 Ejecutando simulación con seed=96
# 🚀 Ejecutando simulación con seed=97
# 🚀 Ejecutando simulación con seed=98
# 🚀 Ejecutando simulación con seed=99
# 🚀 Ejecutando simulación con seed=100
# Se crea archivo 96_4208.json de pacientes (7.56 segundos)
# Se crea archivo 97_4208.json de pacientes (7.54 segundos)
# Se crea archivo 94_4208.json de pacientes (7.57 segundos)
# Se crea archivo 92_4208.json de pacientes (7.55 segundos)
# Se crea archivo 100_4208.json de pacientes (7.61 segundos)
# Se crea archivo 98_4208.json de pacientes (7.67 segundos)
# Se crea archivo 99_4208.json de pacientes (7.79 segundos)
# Se crea archivo 91_4208.json de pacientes (7.76 segundos)
# Se crea archivo 93_4208.json de pacientes (7.79 segundos)
# Se crea archivo 95_4208.json de pacientes (7.86 segundos)
# Pacientes separados por llegada cargados (5.83 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (6.17 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.92 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (6.10 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (6.05 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (6.51 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (6.70 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (6.61 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (6.78 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (6.82 segundos)
# Clase Simulacion instanciada (0.00 segundos)
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
# Simulación finalizada en (22.63 segundos)
# Simulación finalizada en (22.62 segundos)
# Simulación finalizada en (22.86 segundos)
# Simulación finalizada en (22.43 segundos)
# Simulación finalizada en (22.96 segundos)
# Simulación finalizada en (22.03 segundos)
# Simulación finalizada en (22.21 segundos)
# Simulación finalizada en (22.22 segundos)
# Simulación finalizada en (22.41 segundos)
# Simulación finalizada en (22.89 segundos)
# Log de pacientes terminado como DataFrame (8.00 segundos)
# Log de pacientes terminado como DataFrame (8.48 segundos)
# Log de pacientes terminado como DataFrame (9.19 segundos)
# Log de pacientes terminado como DataFrame (9.17 segundos)
# Log de pacientes terminado como DataFrame (9.66 segundos)
# Log de pacientes terminado como DataFrame (9.71 segundos)
# Log de pacientes terminado como DataFrame (9.71 segundos)
# Log de pacientes terminado como DataFrame (9.79 segundos)
# Log de pacientes terminado como DataFrame (9.71 segundos)
# Log de pacientes terminado como DataFrame (9.86 segundos)
# ✅ KPIs calculados en 4.62s
# ✅ KPIs calculados en 5.12s
# ✅ KPIs calculados en 5.22s
# ✅ KPIs calculados en 5.33s
# ✅ KPIs calculados en 5.83s
# ✅ KPIs calculados en 6.00s
# ✅ KPIs calculados en 7.21s
# ✅ KPIs calculados en 7.18s
# ✅ KPIs calculados en 7.19s
# ✅ KPIs calculados en 7.22s
# ✅ Todas las simulaciones han terminado.
