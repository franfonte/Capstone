# %%
import subprocess
import sys
import multiprocessing

def correr_paralelo_consola(seeds, script="run_sim.py"):
    max_procesos = multiprocessing.cpu_count()
    print(f"🧠 Usando hasta {max_procesos} procesos simultáneos.")

    procesos = []

    for seed in seeds:
        print(f"🚀 Ejecutando simulación con seed={seed}")
        p = subprocess.Popen([sys.executable, script, str(seed)])
        procesos.append(p)

        if len(procesos) >= max_procesos:
            for p in procesos:
                p.wait()
            procesos = []

    # Esperar procesos restantes
    for p in procesos:
        p.wait()

    print("✅ Todas las simulaciones han terminado.")

# %%
seeds = list(range(1, 101))
correr_paralelo_consola(seeds)
# Out:
# 🧠 Usando hasta 10 procesos simultáneos.
# 🚀 Ejecutando simulación con seed=1
# 🚀 Ejecutando simulación con seed=2
# 🚀 Ejecutando simulación con seed=3
# 🚀 Ejecutando simulación con seed=4
# 🚀 Ejecutando simulación con seed=5
# 🚀 Ejecutando simulación con seed=6
# 🚀 Ejecutando simulación con seed=7
# 🚀 Ejecutando simulación con seed=8
# 🚀 Ejecutando simulación con seed=9
# 🚀 Ejecutando simulación con seed=10
# Se utiliza archivo existente 3_4208.json de pacientes (0.00 segundos)
# Se utiliza archivo existente 10_4208.json de pacientes (0.00 segundos)
# Se utiliza archivo existente 4_4208.json de pacientes (0.00 segundos)
# Se utiliza archivo existente 8_4208.json de pacientes (0.00 segundos)
# Se utiliza archivo existente 5_4208.json de pacientes (0.00 segundos)
# Se utiliza archivo existente 9_4208.json de pacientes (0.00 segundos)
# Se utiliza archivo existente 2_4208.json de pacientes (0.00 segundos)
# Se utiliza archivo existente 7_4208.json de pacientes (0.00 segundos)
# Se utiliza archivo existente 1_4208.json de pacientes (0.00 segundos)
# Se utiliza archivo existente 6_4208.json de pacientes (0.00 segundos)
# Pacientes separados por llegada cargados (6.08 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (6.21 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (6.34 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (6.47 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (6.58 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (6.62 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (6.64 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (6.63 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (6.61 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (6.71 segundos)
# Clase Simulacion instanciada (0.00 segundos)
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
# Simulación finalizada en (13.69 segundos)
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
# Simulación finalizada en (14.09 segundos)
# Simulación finalizada en (13.63 segundos)
#
# Simulando ciclo 4000 de 4500
# Simulación finalizada en (14.08 segundos)
# Simulación finalizada en (13.77 segundos)
# Simulación finalizada en (14.02 segundos)
# Simulación finalizada en (13.96 segundos)
# Simulación finalizada en (14.20 segundos)
# Simulación finalizada en (14.15 segundos)
# Simulación finalizada en (14.48 segundos)
# Log de pacientes terminado como DataFrame (7.30 segundos)
# Log de pacientes terminado como DataFrame (7.31 segundos)
# Log de pacientes terminado como DataFrame (7.46 segundos)
# Log de pacientes terminado como DataFrame (7.73 segundos)
# Log de pacientes terminado como DataFrame (7.63 segundos)
# Log de pacientes terminado como DataFrame (7.84 segundos)
# Log de pacientes terminado como DataFrame (7.97 segundos)
# Log de pacientes terminado como DataFrame (8.01 segundos)
# Log de pacientes terminado como DataFrame (8.11 segundos)
# Log de pacientes terminado como DataFrame (7.92 segundos)
# ✅ KPIs calculados en 4.14s
# ✅ KPIs calculados en 4.26s
# ✅ KPIs calculados en 4.32s
# ✅ KPIs calculados en 4.32s
# ✅ KPIs calculados en 4.97s
# ✅ KPIs calculados en 5.17s
# ✅ KPIs calculados en 5.54s
# ✅ KPIs calculados en 5.49s
# ✅ KPIs calculados en 5.64s
# ✅ KPIs calculados en 5.68s
# 🚀 Ejecutando simulación con seed=11
# 🚀 Ejecutando simulación con seed=12
# 🚀 Ejecutando simulación con seed=13
# 🚀 Ejecutando simulación con seed=14
# 🚀 Ejecutando simulación con seed=15
# 🚀 Ejecutando simulación con seed=16
# 🚀 Ejecutando simulación con seed=17
# 🚀 Ejecutando simulación con seed=18
# 🚀 Ejecutando simulación con seed=19
# 🚀 Ejecutando simulación con seed=20
# Se utiliza archivo existente 14_4208.json de pacientes (0.00 segundos)
# Se utiliza archivo existente 15_4208.json de pacientes (0.00 segundos)
# Se utiliza archivo existente 13_4208.json de pacientes (0.00 segundos)
# Se utiliza archivo existente 11_4208.json de pacientes (0.00 segundos)
# Se utiliza archivo existente 16_4208.json de pacientes (0.01 segundos)
# Se utiliza archivo existente 12_4208.json de pacientes (0.00 segundos)
# Se utiliza archivo existente 18_4208.json de pacientes (0.00 segundos)
# Se utiliza archivo existente 20_4208.json de pacientes (0.01 segundos)
# Se utiliza archivo existente 17_4208.json de pacientes (0.00 segundos)
# Se utiliza archivo existente 19_4208.json de pacientes (0.00 segundos)
# Pacientes separados por llegada cargados (5.14 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.47 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.63 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.69 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.72 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.68 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.66 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.63 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.85 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.67 segundos)
# Clase Simulacion instanciada (0.00 segundos)
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
# Simulación finalizada en (13.56 segundos)
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
# Simulación finalizada en (13.29 segundos)
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
# Simulación finalizada en (13.56 segundos)
# Simulación finalizada en (13.73 segundos)
# Simulación finalizada en (14.05 segundos)
# Simulación finalizada en (13.88 segundos)
# Simulación finalizada en (13.86 segundos)
# Simulación finalizada en (14.02 segundos)
# Simulación finalizada en (14.14 segundos)
# Simulación finalizada en (14.30 segundos)
# Log de pacientes terminado como DataFrame (3.83 segundos)
# Log de pacientes terminado como DataFrame (7.29 segundos)
# Log de pacientes terminado como DataFrame (8.38 segundos)
# Log de pacientes terminado como DataFrame (8.38 segundos)
# Log de pacientes terminado como DataFrame (9.01 segundos)
# Log de pacientes terminado como DataFrame (9.06 segundos)
# Log de pacientes terminado como DataFrame (9.20 segundos)
# Log de pacientes terminado como DataFrame (9.04 segundos)
# Log de pacientes terminado como DataFrame (9.29 segundos)
# Log de pacientes terminado como DataFrame (9.27 segundos)
# ✅ KPIs calculados en 4.23s
# ✅ KPIs calculados en 3.75s
# ✅ KPIs calculados en 4.35s
# ✅ KPIs calculados en 4.74s
# ✅ KPIs calculados en 5.05s
# ✅ KPIs calculados en 5.22s
# ✅ KPIs calculados en 5.34s
# ✅ KPIs calculados en 5.51s
# ✅ KPIs calculados en 5.67s
# ✅ KPIs calculados en 5.85s
# 🚀 Ejecutando simulación con seed=21
# 🚀 Ejecutando simulación con seed=22
# 🚀 Ejecutando simulación con seed=23
# 🚀 Ejecutando simulación con seed=24
# 🚀 Ejecutando simulación con seed=25
# 🚀 Ejecutando simulación con seed=26
# 🚀 Ejecutando simulación con seed=27
# 🚀 Ejecutando simulación con seed=28
# 🚀 Ejecutando simulación con seed=29
# 🚀 Ejecutando simulación con seed=30
# Se utiliza archivo existente 29_4208.json de pacientes (0.00 segundos)
# Se utiliza archivo existente 21_4208.json de pacientes (0.00 segundos)
# Se utiliza archivo existente 24_4208.json de pacientes (0.00 segundos)
# Se utiliza archivo existente 23_4208.json de pacientes (0.00 segundos)
# Se utiliza archivo existente 27_4208.json de pacientes (0.01 segundos)
# Se utiliza archivo existente 22_4208.json de pacientes (0.00 segundos)
# Se utiliza archivo existente 28_4208.json de pacientes (0.00 segundos)
# Se utiliza archivo existente 26_4208.json de pacientes (0.00 segundos)
# Se utiliza archivo existente 25_4208.json de pacientes (0.00 segundos)
# Se utiliza archivo existente 30_4208.json de pacientes (0.00 segundos)
# Pacientes separados por llegada cargados (5.42 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.37 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.32 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.35 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.48 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.38 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.48 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.52 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.62 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.59 segundos)
# Clase Simulacion instanciada (0.00 segundos)
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
# Simulación finalizada en (13.19 segundos)
#
# Simulando ciclo 4000 de 4500
# Simulación finalizada en (13.25 segundos)
# Simulación finalizada en (13.06 segundos)
# Simulación finalizada en (13.13 segundos)
# Simulación finalizada en (13.32 segundos)
# Simulación finalizada en (13.28 segundos)
# Simulación finalizada en (13.30 segundos)
# Simulación finalizada en (13.32 segundos)
# Simulación finalizada en (13.63 segundos)
# Simulación finalizada en (13.50 segundos)
# Log de pacientes terminado como DataFrame (6.40 segundos)
# Log de pacientes terminado como DataFrame (6.86 segundos)
# Log de pacientes terminado como DataFrame (6.99 segundos)
# Log de pacientes terminado como DataFrame (7.16 segundos)
# Log de pacientes terminado como DataFrame (7.51 segundos)
# Log de pacientes terminado como DataFrame (7.51 segundos)
# Log de pacientes terminado como DataFrame (7.51 segundos)
# Log de pacientes terminado como DataFrame (7.62 segundos)
# Log de pacientes terminado como DataFrame (7.62 segundos)
# Log de pacientes terminado como DataFrame (7.52 segundos)
# ✅ KPIs calculados en 3.83s
# ✅ KPIs calculados en 3.77s
# ✅ KPIs calculados en 4.05s
# ✅ KPIs calculados en 4.84s
# ✅ KPIs calculados en 5.01s
# ✅ KPIs calculados en 5.36s
# ✅ KPIs calculados en 5.25s
# ✅ KPIs calculados en 5.16s
# ✅ KPIs calculados en 5.34s
# ✅ KPIs calculados en 5.20s
# 🚀 Ejecutando simulación con seed=31
# 🚀 Ejecutando simulación con seed=32
# 🚀 Ejecutando simulación con seed=33
# 🚀 Ejecutando simulación con seed=34
# 🚀 Ejecutando simulación con seed=35
# 🚀 Ejecutando simulación con seed=36
# 🚀 Ejecutando simulación con seed=37
# 🚀 Ejecutando simulación con seed=38
# 🚀 Ejecutando simulación con seed=39
# 🚀 Ejecutando simulación con seed=40
# Se utiliza archivo existente 35_4208.json de pacientes (0.00 segundos)
# Se utiliza archivo existente 39_4208.json de pacientes (0.00 segundos)
# Se utiliza archivo existente 38_4208.json de pacientes (0.00 segundos)
# Se utiliza archivo existente 32_4208.json de pacientes (0.00 segundos)
# Se utiliza archivo existente 34_4208.json de pacientes (0.01 segundos)
# Se utiliza archivo existente 33_4208.json de pacientes (0.01 segundos)
# Se utiliza archivo existente 31_4208.json de pacientes (0.01 segundos)
# Se utiliza archivo existente 36_4208.json de pacientes (0.00 segundos)
# Se utiliza archivo existente 37_4208.json de pacientes (0.02 segundos)
# Se utiliza archivo existente 40_4208.json de pacientes (0.02 segundos)
# Pacientes separados por llegada cargados (5.17 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.38 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.38 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.47 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.44 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.44 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.54 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.57 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.56 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.64 segundos)
# Clase Simulacion instanciada (0.00 segundos)
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
# Simulación finalizada en (13.35 segundos)
#
# Simulando ciclo 4000 de 4500
# Simulación finalizada en (13.18 segundos)
# Simulación finalizada en (13.13 segundos)
# Simulación finalizada en (13.31 segundos)
# Simulación finalizada en (13.28 segundos)
#
# Simulando ciclo 4000 de 4500
# Simulación finalizada en (13.52 segundos)
# Simulación finalizada en (13.40 segundos)
# Simulación finalizada en (13.51 segundos)
# Simulación finalizada en (13.55 segundos)
# Simulación finalizada en (14.13 segundos)
# Log de pacientes terminado como DataFrame (4.40 segundos)
# Log de pacientes terminado como DataFrame (6.88 segundos)
# Log de pacientes terminado como DataFrame (7.15 segundos)
# Log de pacientes terminado como DataFrame (7.40 segundos)
# Log de pacientes terminado como DataFrame (7.54 segundos)
# Log de pacientes terminado como DataFrame (7.60 segundos)
# Log de pacientes terminado como DataFrame (7.83 segundos)
# Log de pacientes terminado como DataFrame (7.84 segundos)
# Log de pacientes terminado como DataFrame (7.76 segundos)
# Log de pacientes terminado como DataFrame (7.52 segundos)
# ✅ KPIs calculados en 3.64s
# ✅ KPIs calculados en 4.17s
# ✅ KPIs calculados en 4.79s
# ✅ KPIs calculados en 5.09s
# ✅ KPIs calculados en 5.14s
# ✅ KPIs calculados en 5.26s
# ✅ KPIs calculados en 5.28s
# ✅ KPIs calculados en 5.34s
# ✅ KPIs calculados en 5.54s
# ✅ KPIs calculados en 5.38s
# 🚀 Ejecutando simulación con seed=41
# 🚀 Ejecutando simulación con seed=42
# 🚀 Ejecutando simulación con seed=43
# 🚀 Ejecutando simulación con seed=44
# 🚀 Ejecutando simulación con seed=45
# 🚀 Ejecutando simulación con seed=46
# 🚀 Ejecutando simulación con seed=47
# 🚀 Ejecutando simulación con seed=48
# 🚀 Ejecutando simulación con seed=49
# 🚀 Ejecutando simulación con seed=50
# Se utiliza archivo existente 48_4208.json de pacientes (0.00 segundos)
# Se utiliza archivo existente 43_4208.json de pacientes (0.00 segundos)
# Se utiliza archivo existente 50_4208.json de pacientes (0.00 segundos)
# Se utiliza archivo existente 49_4208.json de pacientes (0.00 segundos)
# Se utiliza archivo existente 45_4208.json de pacientes (0.01 segundos)
# Se utiliza archivo existente 41_4208.json de pacientes (0.00 segundos)
# Se utiliza archivo existente 46_4208.json de pacientes (0.00 segundos)
# Se utiliza archivo existente 44_4208.json de pacientes (0.00 segundos)
# Se utiliza archivo existente 47_4208.json de pacientes (0.02 segundos)
# Se utiliza archivo existente 42_4208.json de pacientes (0.00 segundos)
# Pacientes separados por llegada cargados (5.06 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.02 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.33 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.35 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.63 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.65 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.60 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.67 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.62 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.68 segundos)
# Clase Simulacion instanciada (0.00 segundos)
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
# Simulación finalizada en (13.36 segundos)
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
# Simulación finalizada en (13.53 segundos)
# Simulación finalizada en (13.46 segundos)
# Simulación finalizada en (13.22 segundos)
# Simulación finalizada en (13.25 segundos)
# Simulación finalizada en (13.35 segundos)
# Simulación finalizada en (13.45 segundos)
# Simulación finalizada en (13.52 segundos)
# Simulación finalizada en (13.85 segundos)
# Simulación finalizada en (13.62 segundos)
# Log de pacientes terminado como DataFrame (5.92 segundos)
# Log de pacientes terminado como DataFrame (6.90 segundos)
# Log de pacientes terminado como DataFrame (7.00 segundos)
# Log de pacientes terminado como DataFrame (7.02 segundos)
# Log de pacientes terminado como DataFrame (6.95 segundos)
# Log de pacientes terminado como DataFrame (7.36 segundos)
# Log de pacientes terminado como DataFrame (7.53 segundos)
# Log de pacientes terminado como DataFrame (7.50 segundos)
# Log de pacientes terminado como DataFrame (7.49 segundos)
# Log de pacientes terminado como DataFrame (7.52 segundos)
# ✅ KPIs calculados en 3.33s
# ✅ KPIs calculados en 4.36s
# ✅ KPIs calculados en 4.72s
# ✅ KPIs calculados en 4.83s
# ✅ KPIs calculados en 4.89s
# ✅ KPIs calculados en 4.90s
# ✅ KPIs calculados en 5.19s
# ✅ KPIs calculados en 5.15s
# ✅ KPIs calculados en 5.19s
# ✅ KPIs calculados en 5.42s
# 🚀 Ejecutando simulación con seed=51
# 🚀 Ejecutando simulación con seed=52
# 🚀 Ejecutando simulación con seed=53
# 🚀 Ejecutando simulación con seed=54
# 🚀 Ejecutando simulación con seed=55
# 🚀 Ejecutando simulación con seed=56
# 🚀 Ejecutando simulación con seed=57
# 🚀 Ejecutando simulación con seed=58
# 🚀 Ejecutando simulación con seed=59
# 🚀 Ejecutando simulación con seed=60
# Se utiliza archivo existente 52_4208.json de pacientes (0.00 segundos)
# Se utiliza archivo existente 56_4208.json de pacientes (0.00 segundos)
# Se utiliza archivo existente 55_4208.json de pacientes (0.00 segundos)
# Se utiliza archivo existente 57_4208.json de pacientes (0.00 segundos)
# Se utiliza archivo existente 54_4208.json de pacientes (0.00 segundos)
# Se utiliza archivo existente 51_4208.json de pacientes (0.00 segundos)
# Se utiliza archivo existente 60_4208.json de pacientes (0.02 segundos)
# Se utiliza archivo existente 53_4208.json de pacientes (0.02 segundos)
# Se utiliza archivo existente 59_4208.json de pacientes (0.02 segundos)
# Se utiliza archivo existente 58_4208.json de pacientes (0.00 segundos)
# Pacientes separados por llegada cargados (5.39 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.15 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.39 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.49 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.62 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.69 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.66 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.69 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.66 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.83 segundos)
# Clase Simulacion instanciada (0.00 segundos)
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
# Simulación finalizada en (13.35 segundos)
# Simulación finalizada en (13.50 segundos)
# Simulación finalizada en (13.22 segundos)
#
# Simulando ciclo 4000 de 4500
# Simulación finalizada en (13.04 segundos)
# Simulación finalizada en (13.37 segundos)
# Simulación finalizada en (13.24 segundos)
# Simulación finalizada en (13.34 segundos)
# Simulación finalizada en (13.36 segundos)
# Simulación finalizada en (13.40 segundos)
# Simulación finalizada en (13.84 segundos)
# Log de pacientes terminado como DataFrame (7.68 segundos)
# Log de pacientes terminado como DataFrame (8.06 segundos)
# Log de pacientes terminado como DataFrame (8.22 segundos)
# Log de pacientes terminado como DataFrame (8.29 segundos)
# Log de pacientes terminado como DataFrame (8.37 segundos)
# Log de pacientes terminado como DataFrame (8.47 segundos)
# Log de pacientes terminado como DataFrame (8.53 segundos)
# Log de pacientes terminado como DataFrame (8.77 segundos)
# Log de pacientes terminado como DataFrame (8.85 segundos)
# Log de pacientes terminado como DataFrame (8.67 segundos)
# ✅ KPIs calculados en 4.79s
# ✅ KPIs calculados en 4.39s
# ✅ KPIs calculados en 4.65s
# ✅ KPIs calculados en 4.67s
# ✅ KPIs calculados en 4.75s
# ✅ KPIs calculados en 4.57s
# ✅ KPIs calculados en 4.74s
# ✅ KPIs calculados en 5.08s
# ✅ KPIs calculados en 5.28s
# ✅ KPIs calculados en 5.58s
# 🚀 Ejecutando simulación con seed=61
# 🚀 Ejecutando simulación con seed=62
# 🚀 Ejecutando simulación con seed=63
# 🚀 Ejecutando simulación con seed=64
# 🚀 Ejecutando simulación con seed=65
# 🚀 Ejecutando simulación con seed=66
# 🚀 Ejecutando simulación con seed=67
# 🚀 Ejecutando simulación con seed=68
# 🚀 Ejecutando simulación con seed=69
# 🚀 Ejecutando simulación con seed=70
# Se utiliza archivo existente 64_4208.json de pacientes (0.00 segundos)
# Se utiliza archivo existente 69_4208.json de pacientes (0.00 segundos)
# Se utiliza archivo existente 62_4208.json de pacientes (0.00 segundos)
# Se utiliza archivo existente 70_4208.json de pacientes (0.00 segundos)
# Se utiliza archivo existente 68_4208.json de pacientes (0.00 segundos)
# Se utiliza archivo existente 66_4208.json de pacientes (0.00 segundos)
# Se utiliza archivo existente 65_4208.json de pacientes (0.00 segundos)
# Se utiliza archivo existente 61_4208.json de pacientes (0.01 segundos)
# Se utiliza archivo existente 67_4208.json de pacientes (0.02 segundos)
# Se utiliza archivo existente 63_4208.json de pacientes (0.02 segundos)
# Pacientes separados por llegada cargados (5.56 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.36 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.37 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.35 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.32 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.39 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.51 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.51 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.53 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.69 segundos)
# Clase Simulacion instanciada (0.00 segundos)
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
# Simulación finalizada en (13.57 segundos)
# Simulación finalizada en (13.18 segundos)
#
# Simulando ciclo 4000 de 4500
# Simulación finalizada en (13.32 segundos)
# Simulación finalizada en (13.36 segundos)
# Simulación finalizada en (13.24 segundos)
# Simulación finalizada en (13.43 segundos)
# Simulación finalizada en (13.51 segundos)
# Simulación finalizada en (13.63 segundos)
# Simulación finalizada en (13.77 segundos)
# Simulación finalizada en (13.62 segundos)
# Log de pacientes terminado como DataFrame (7.06 segundos)
# Log de pacientes terminado como DataFrame (7.29 segundos)
# Log de pacientes terminado como DataFrame (7.52 segundos)
# Log de pacientes terminado como DataFrame (7.65 segundos)
# Log de pacientes terminado como DataFrame (7.63 segundos)
# Log de pacientes terminado como DataFrame (8.00 segundos)
# Log de pacientes terminado como DataFrame (8.07 segundos)
# Log de pacientes terminado como DataFrame (8.11 segundos)
# Log de pacientes terminado como DataFrame (8.15 segundos)
# Log de pacientes terminado como DataFrame (7.97 segundos)
# ✅ KPIs calculados en 4.11s
# ✅ KPIs calculados en 4.10s
# ✅ KPIs calculados en 4.27s
# ✅ KPIs calculados en 4.32s
# ✅ KPIs calculados en 4.31s
# ✅ KPIs calculados en 4.86s
# ✅ KPIs calculados en 5.23s
# ✅ KPIs calculados en 5.37s
# ✅ KPIs calculados en 5.68s
# ✅ KPIs calculados en 5.67s
# 🚀 Ejecutando simulación con seed=71
# 🚀 Ejecutando simulación con seed=72
# 🚀 Ejecutando simulación con seed=73
# 🚀 Ejecutando simulación con seed=74
# 🚀 Ejecutando simulación con seed=75
# 🚀 Ejecutando simulación con seed=76
# 🚀 Ejecutando simulación con seed=77
# 🚀 Ejecutando simulación con seed=78
# 🚀 Ejecutando simulación con seed=79
# 🚀 Ejecutando simulación con seed=80
# Se utiliza archivo existente 74_4208.json de pacientes (0.00 segundos)
# Se utiliza archivo existente 78_4208.json de pacientes (0.00 segundos)
# Se utiliza archivo existente 77_4208.json de pacientes (0.00 segundos)
# Se utiliza archivo existente 76_4208.json de pacientes (0.00 segundos)
# Se utiliza archivo existente 71_4208.json de pacientes (0.00 segundos)
# Se utiliza archivo existente 79_4208.json de pacientes (0.00 segundos)
# Se utiliza archivo existente 80_4208.json de pacientes (0.00 segundos)
# Se utiliza archivo existente 73_4208.json de pacientes (0.01 segundos)
# Se utiliza archivo existente 75_4208.json de pacientes (0.01 segundos)
# Se utiliza archivo existente 72_4208.json de pacientes (0.01 segundos)
# Pacientes separados por llegada cargados (5.77 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.29 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.41 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.38 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.35 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.40 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.39 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.39 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.39 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.41 segundos)
# Clase Simulacion instanciada (0.00 segundos)
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
# Simulación finalizada en (13.54 segundos)
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
# Simulación finalizada en (13.33 segundos)
# Simulación finalizada en (13.43 segundos)
# Simulación finalizada en (13.59 segundos)
# Simulación finalizada en (13.58 segundos)
# Simulación finalizada en (13.55 segundos)
# Simulación finalizada en (13.69 segundos)
# Simulación finalizada en (13.76 segundos)
# Simulación finalizada en (13.94 segundos)
# Simulación finalizada en (13.84 segundos)
# Log de pacientes terminado como DataFrame (6.84 segundos)
# Log de pacientes terminado como DataFrame (7.61 segundos)
# Log de pacientes terminado como DataFrame (8.14 segundos)
# Log de pacientes terminado como DataFrame (8.40 segundos)
# Log de pacientes terminado como DataFrame (8.49 segundos)
# Log de pacientes terminado como DataFrame (8.18 segundos)
# Log de pacientes terminado como DataFrame (8.53 segundos)
# Log de pacientes terminado como DataFrame (8.54 segundos)
# Log de pacientes terminado como DataFrame (8.54 segundos)
# Log de pacientes terminado como DataFrame (8.67 segundos)
# ✅ KPIs calculados en 3.60s
# ✅ KPIs calculados en 3.75s
# ✅ KPIs calculados en 4.93s
# ✅ KPIs calculados en 5.03s
# ✅ KPIs calculados en 5.03s
# ✅ KPIs calculados en 5.00s
# ✅ KPIs calculados en 5.10s
# ✅ KPIs calculados en 5.18s
# ✅ KPIs calculados en 4.92s
# ✅ KPIs calculados en 4.88s
# 🚀 Ejecutando simulación con seed=81
# 🚀 Ejecutando simulación con seed=82
# 🚀 Ejecutando simulación con seed=83
# 🚀 Ejecutando simulación con seed=84
# 🚀 Ejecutando simulación con seed=85
# 🚀 Ejecutando simulación con seed=86
# 🚀 Ejecutando simulación con seed=87
# 🚀 Ejecutando simulación con seed=88
# 🚀 Ejecutando simulación con seed=89
# 🚀 Ejecutando simulación con seed=90
# Se utiliza archivo existente 86_4208.json de pacientes (0.00 segundos)
# Se utiliza archivo existente 85_4208.json de pacientes (0.00 segundos)
# Se utiliza archivo existente 88_4208.json de pacientes (0.00 segundos)
# Se utiliza archivo existente 84_4208.json de pacientes (0.00 segundos)
# Se utiliza archivo existente 82_4208.json de pacientes (0.00 segundos)
# Se utiliza archivo existente 83_4208.json de pacientes (0.01 segundos)
# Se utiliza archivo existente 90_4208.json de pacientes (0.01 segundos)
# Se utiliza archivo existente 89_4208.json de pacientes (0.01 segundos)
# Se utiliza archivo existente 87_4208.json de pacientes (0.02 segundos)
# Se utiliza archivo existente 81_4208.json de pacientes (0.01 segundos)
# Pacientes separados por llegada cargados (5.26 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.28 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.45 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.63 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.55 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.59 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.59 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.63 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.69 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.73 segundos)
# Clase Simulacion instanciada (0.00 segundos)
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
# Simulación finalizada en (13.03 segundos)
# Simulación finalizada en (13.76 segundos)
# Simulación finalizada en (13.10 segundos)
# Simulación finalizada en (13.14 segundos)
# Simulación finalizada en (13.56 segundos)
# Simulación finalizada en (13.15 segundos)
# Simulación finalizada en (13.28 segundos)
# Simulación finalizada en (13.52 segundos)
# Simulación finalizada en (13.81 segundos)
# Simulación finalizada en (13.43 segundos)
# Log de pacientes terminado como DataFrame (7.18 segundos)
# Log de pacientes terminado como DataFrame (7.44 segundos)
# Log de pacientes terminado como DataFrame (7.56 segundos)
# Log de pacientes terminado como DataFrame (7.55 segundos)
# Log de pacientes terminado como DataFrame (7.67 segundos)
# Log de pacientes terminado como DataFrame (8.08 segundos)
# Log de pacientes terminado como DataFrame (7.91 segundos)
# Log de pacientes terminado como DataFrame (7.92 segundos)
# Log de pacientes terminado como DataFrame (7.93 segundos)
# Log de pacientes terminado como DataFrame (8.02 segundos)
# ✅ KPIs calculados en 4.34s
# ✅ KPIs calculados en 4.43s
# ✅ KPIs calculados en 4.52s
# ✅ KPIs calculados en 4.77s
# ✅ KPIs calculados en 4.98s
# ✅ KPIs calculados en 5.21s
# ✅ KPIs calculados en 5.39s
# ✅ KPIs calculados en 5.40s
# ✅ KPIs calculados en 5.47s
# ✅ KPIs calculados en 5.39s
# 🚀 Ejecutando simulación con seed=91
# 🚀 Ejecutando simulación con seed=92
# 🚀 Ejecutando simulación con seed=93
# 🚀 Ejecutando simulación con seed=94
# 🚀 Ejecutando simulación con seed=95
# 🚀 Ejecutando simulación con seed=96
# 🚀 Ejecutando simulación con seed=97
# 🚀 Ejecutando simulación con seed=98
# 🚀 Ejecutando simulación con seed=99
# 🚀 Ejecutando simulación con seed=100
# Se utiliza archivo existente 94_4208.json de pacientes (0.00 segundos)
# Se utiliza archivo existente 95_4208.json de pacientes (0.00 segundos)
# Se utiliza archivo existente 97_4208.json de pacientes (0.00 segundos)
# Se utiliza archivo existente 93_4208.json de pacientes (0.02 segundos)
# Se utiliza archivo existente 91_4208.json de pacientes (0.02 segundos)
# Se utiliza archivo existente 96_4208.json de pacientes (0.02 segundos)
# Se utiliza archivo existente 98_4208.json de pacientes (0.01 segundos)
# Se utiliza archivo existente 100_4208.json de pacientes (0.02 segundos)
# Se utiliza archivo existente 99_4208.json de pacientes (0.02 segundos)
# Se utiliza archivo existente 92_4208.json de pacientes (0.03 segundos)
# Pacientes separados por llegada cargados (5.44 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.47 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.46 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.48 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.50 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.54 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.58 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.69 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.72 segundos)
# Clase Simulacion instanciada (0.00 segundos)
# Pacientes separados por llegada cargados (5.79 segundos)
# Clase Simulacion instanciada (0.00 segundos)
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 1000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 2000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 3000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
#
# Simulando ciclo 4000 de 4500
# Simulación finalizada en (13.17 segundos)
# Simulación finalizada en (13.14 segundos)
# Simulación finalizada en (13.28 segundos)
# Simulación finalizada en (13.26 segundos)
# Simulación finalizada en (13.03 segundos)
# Simulación finalizada en (13.54 segundos)
# Simulación finalizada en (13.46 segundos)
# Simulación finalizada en (13.70 segundos)
# Simulación finalizada en (13.52 segundos)
# Simulación finalizada en (13.62 segundos)
# Log de pacientes terminado como DataFrame (6.86 segundos)
# Log de pacientes terminado como DataFrame (7.44 segundos)
# Log de pacientes terminado como DataFrame (7.45 segundos)
# Log de pacientes terminado como DataFrame (7.59 segundos)
# Log de pacientes terminado como DataFrame (7.66 segundos)
# Log de pacientes terminado como DataFrame (7.83 segundos)
# Log de pacientes terminado como DataFrame (7.93 segundos)
# Log de pacientes terminado como DataFrame (7.90 segundos)
# Log de pacientes terminado como DataFrame (7.84 segundos)
# Log de pacientes terminado como DataFrame (7.79 segundos)
# ✅ KPIs calculados en 4.58s
# ✅ KPIs calculados en 4.65s
# ✅ KPIs calculados en 4.70s
# ✅ KPIs calculados en 4.76s
# ✅ KPIs calculados en 4.67s
# ✅ KPIs calculados en 5.14s
# ✅ KPIs calculados en 4.99s
# ✅ KPIs calculados en 5.11s
# ✅ KPIs calculados en 5.34s
# ✅ KPIs calculados en 5.20s
# ✅ Todas las simulaciones han terminado.
